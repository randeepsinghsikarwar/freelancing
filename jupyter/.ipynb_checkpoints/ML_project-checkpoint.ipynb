# %% [markdown]
# ### Part 1 - Create and evaluate an initial model

# %% [markdown]
# __EXPLANATION__
# provided the dataset, we are about to train a random forest model to predict New York City rent prices.
# before training the model, the dataset will go through a data cleaning process where we will be modifying the dataset in a way that is appropriate for training a model.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('rent_8.csv')
print(data.shape)
# Out:
# (20000, 15)

# %%
data.head(2)
# Out:
#    bathrooms  bedrooms                       building_id              created  \
# 0        1.0         1  ec0d62637d75f9d7207d9f9bbc939a28  2016-05-10 03:31:32
# 1        1.0         2                                 0  2016-06-17 01:22:53
#
#                                          description   display_address  \
# 0  MARVELOUS one bedroom in Upper East Side...sho...       E 95 Street
# 1  Gorgeous 2 bedroom (Queen size bedrooms) and 1...  East 32nd Street
#
#                                             features  latitude  longitude  \
# 0                                ['Hardwood Floors']   40.7827   -73.9461
# 1  ['Doorman', 'Multi-Level', 'Pre-War', 'Dogs Al...   40.7471   -73.9846
#
#                          manager_id  \
# 0  ed17ada77c1b94b4fb00d126a0c2ea06
# 1  ad2928226654cf28722d0dee31e54040
#
#                                               photos  price  \
# 0                                                 []   1850
# 1  ['https://photos.renthop.com/2/7174539_b4c0ff6...   3775
#
#          street_address  interest_level  num_desc_words
# 0       332 E 95 Street               1              30
# 1  7-9 East 32nd Street               1              59

# %%
data.head(2).T #transpose of dataframe.
# Out:
#                                                                  0  \
# bathrooms                                                      1.0
# bedrooms                                                         1
# building_id                       ec0d62637d75f9d7207d9f9bbc939a28
# created                                        2016-05-10 03:31:32
# description      MARVELOUS one bedroom in Upper East Side...sho...
# display_address                                        E 95 Street
# features                                       ['Hardwood Floors']
# latitude                                                   40.7827
# longitude                                                 -73.9461
# manager_id                        ed17ada77c1b94b4fb00d126a0c2ea06
# photos                                                          []
# price                                                         1850
# street_address                                     332 E 95 Street
# interest_level                                                   1
# num_desc_words                                                  30
#
#                                                                  1
# bathrooms                                                      1.0
# bedrooms                                                         2
# building_id                                                      0
# created                                        2016-06-17 01:22:53
# description      Gorgeous 2 bedroom (Queen size bedrooms) and 1...
# display_address                                   East 32nd Street
# features         ['Doorman', 'Multi-Level', 'Pre-War', 'Dogs Al...
# latitude                                                   40.7471
# longitude                                                 -73.9846
# manager_id                        ad2928226654cf28722d0dee31e54040
# photos           ['https://photos.renthop.com/2/7174539_b4c0ff6...
# price                                                         3775
# street_address                                7-9 East 32nd Street
# interest_level                                                   1
# num_desc_words                                                  59

# %%
data.info()
#last column specift the data type of the column.
#here, object is equivalent to string data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bathrooms        20000 non-null  float64
#  1   bedrooms         20000 non-null  int64
#  2   building_id      20000 non-null  object
#  3   created          20000 non-null  object
#  4   description      19391 non-null  object
#  5   display_address  19934 non-null  object
#  6   features         20000 non-null  object
#  7   latitude         20000 non-null  float64
#  8   longitude        20000 non-null  float64
#  9   manager_id       20000 non-null  object
#  10  photos           20000 non-null  object
#  11  price            20000 non-null  int64
#  12  street_address   19996 non-null  object
#  13  interest_level   20000 non-null  int64
#  14  num_desc_words   20000 non-null  int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 2.3+ MB

# %%
#creating a subset of original data because we want only numeric data, rather than non numeric data. 
num_data = data[['bathrooms', 'bedrooms', 'longitude', 'latitude', 'price']]
num_data.head(2)
# Out:
#    bathrooms  bedrooms  longitude  latitude  price
# 0        1.0         1   -73.9461   40.7827   1850
# 1        1.0         2   -73.9846   40.7471   3775

# %%
#checking if there are any missing values in the columns. 
print(num_data.isnull().any())
# Out:
# bathrooms    False
# bedrooms     False
# longitude    False
# latitude     False
# price        False
# dtype: bool

# %% [markdown]
# __FEATURE AND TARGET SEPARATION__

# %%
x_train = num_data.drop('price', axis=1)
y_train = num_data['price']

# %%
#creating model
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, oob_score = True)

# %%
#fitting model to the training data.
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, oob_score=True)

# %%
r2 = rf.score(x_train, y_train)
print(f"{r2:.4f}")
# Out:
# 0.8534

# %% [markdown]
# __NOTE! the OOB score is computed as the number of correctly predicted rows from the out of bag sample.__

# %%
noisy_oob = rf.oob_score_
print(f"OOB Score {noisy_oob:.4f}")
# Out:
# OOB Score 0.0487

# %% [markdown]
# __AVERAGE OOB SCORE AFTER PERFORMING 10 RUNS__

# %%
scores = []
i = 0
while i<10:
    rf.fit(x_train,y_train)
    oob_score = rf.oob_score_
    scores.append(oob_score)
    i+=1

# %%
avg_oob_score = np.mean(scores)
print(avg_oob_score)
# Out:
# 0.046721490195516004

# %% [markdown]
# ### Part 2 - Denoise the data
#
# __EXPLANATION__
# Performing EDA (exploratory data analysis) where we will explore data to find anomalies. such as weird prices of apartments, and finding hotels that are only in New York.
#
# here, for the price factor, we are assuming the lowest price can be at least 900 dollars which might contain all basic amenities such as doors, windows, and so on. As for the upper limit, we are considering 9000 dollars. as for the latitude and longitude, we will select only essential range and ignore all other values such as 0 or coordinates which does not belong to New York.

# %%
num_data.describe()
# Out:
#           bathrooms      bedrooms     longitude      latitude         price
# count  20000.000000  20000.000000  20000.000000  20000.000000  2.000000e+04
# mean       1.209850      1.542700    -67.830865     40.514548  3.538713e+03
# std        0.499575      1.119214     28.338739      4.987450  8.549412e+03
# min        0.000000      0.000000   -118.271000      0.000000 -1.700000e+04
# 25%        1.000000      1.000000    -73.990900     40.726600  2.450000e+03
# 50%        1.000000      1.000000    -73.976000     40.752100  3.100000e+03
# 75%        1.000000      2.000000    -73.952300     40.775400  4.000000e+03
# max        7.000000      7.000000     88.289200     58.321800  1.150000e+06

# %%
print(num_data.bathrooms.value_counts())
# Out:
# bathrooms
# 1.0    16025
# 2.0     3088
# 3.0      284
# 1.5      253
# 0.0      123
# 2.5      104
# 4.0       71
# 3.5       28
# 5.0       11
# 4.5        7
# 5.5        3
# 7.0        1
# 6.0        1
# 6.5        1
# Name: count, dtype: int64

# %%
print(num_data.bedrooms.value_counts())
# Out:
# bedrooms
# 1    6383
# 2    5916
# 0    3846
# 3    2947
# 4     770
# 5     111
# 6      26
# 7       1
# Name: count, dtype: int64

# %%
clean_data = num_data[(num_data.price > 900) & (num_data.price < 9_000)]

# %%
clean_data.describe()
# Out:
#           bathrooms      bedrooms     longitude      latitude         price
# count  19044.000000  19044.000000  19044.000000  19044.000000  19044.000000
# mean       1.172758      1.505461    -67.789548     40.498787   3405.922968
# std        0.417111      1.090709     28.475120      5.007054   1347.038277
# min        0.000000      0.000000   -118.271000      0.000000    950.000000
# 25%        1.000000      1.000000    -73.991000     40.726400   2495.000000
# 50%        1.000000      1.000000    -73.976100     40.751600   3100.000000
# 75%        1.000000      2.000000    -73.952000     40.775200   3995.000000
# max        4.500000      6.000000     88.289200     58.321800   8995.000000

# %%
clean_data = clean_data[(clean_data.longitude!=0) | (clean_data.latitude!=0)]
clean_data = clean_data[(clean_data['latitude']>40.55) &
                    (clean_data['latitude']<40.94) &
                    (clean_data['longitude']>-74.1) &
                    (clean_data['longitude']<-73.67)]

# %%
clean_data.describe()
# Out:
#           bathrooms      bedrooms     longitude      latitude         price
# count  18100.000000  18100.000000  18100.000000  18100.000000  18100.000000
# mean       1.172928      1.506464    -73.972336     40.750725   3407.803591
# std        0.415807      1.089869      0.029602      0.040048   1349.236917
# min        0.000000      0.000000    -74.085200     40.571200    950.000000
# 25%        1.000000      1.000000    -73.991800     40.727900   2495.000000
# 50%        1.000000      1.000000    -73.977900     40.751700   3100.000000
# 75%        1.000000      2.000000    -73.954600     40.774100   3995.000000
# max        4.000000      6.000000    -73.700100     40.915400   8995.000000

# %%
x,y = clean_data.drop('price', axis=1), clean_data['price']
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, oob_score=True)
rf.fit(x,y)
clean_oob_r2 = rf.oob_score_
print(f"Validation OOB score {clean_oob_r2:.4f}")
# Out:
# Validation OOB score 0.8270

# %% [markdown]
# __AVERAGE OOB SCORE AFTER PERFORMING 10 RUNS__

# %%
scores = []
i = 0
while i<10:
    rf.fit(x,y)
    oob_score = rf.oob_score_
    scores.append(oob_score)
    i+=1

# %%
avg_clean_oob = np.mean(scores)
print(avg_clean_oob)
# Out:
# 0.8269900191170165
