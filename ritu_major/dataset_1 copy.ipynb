# %%
import pandas as pd
# %pip install category_encoders
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


from sklearn.metrics import mean_absolute_error, r2_score
import numpy as np
# Out:
# Requirement already satisfied: category_encoders in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (2.6.3)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.14.0 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.26.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.4.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.12.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (2.2.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.4)
# Requirement already satisfied: six in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\rande\appdata\local\programs\python\python312\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.2)

# %%
df = pd.read_csv('Coffee_Qlty.csv')
df.head(5)
# Out:
#    REC_ID  Species Continent.of.Origin Country.of.Origin  Harvest.Year  \
# 0       0  Arabica              Africa          Ethiopia        2014.0
# 1       1  Arabica              Africa          Ethiopia        2014.0
# 2       2  Arabica       North America         Guatemala           NaN
# 3       3  Arabica              Africa          Ethiopia        2014.0
# 4       4  Arabica              Africa          Ethiopia        2014.0
#
#   Expiration  Variety  Color Processing.Method  Aroma  ...  Acidity  Body  \
# 0   04/03/16      NaN  Green      Washed / Wet   8.67  ...     8.75  8.50
# 1   04/03/16    Other  Green      Washed / Wet   8.75  ...     8.58  8.42
# 2   05/31/11  Bourbon    NaN               NaN   8.42  ...     8.42  8.33
# 3   03/25/16      NaN  Green     Natural / Dry   8.17  ...     8.42  8.50
# 4   04/03/16    Other  Green      Washed / Wet   8.25  ...     8.50  8.42
#
#    Balance  Uniformity  Clean.Cup  Sweetness  Moisture  Quakers  \
# 0     8.42        10.0       10.0       10.0      0.12        0
# 1     8.42        10.0       10.0       10.0      0.12        0
# 2     8.42        10.0       10.0       10.0      0.00        0
# 3     8.25        10.0       10.0       10.0      0.11        0
# 4     8.33        10.0       10.0       10.0      0.12        0
#
#    Category.One.Defects  Category.Two.Defects
# 0                     0                     0
# 1                     0                     1
# 2                     0                     0
# 3                     0                     2
# 4                     0                     2
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# REC_ID                    int64
# Species                  object
# Continent.of.Origin      object
# Country.of.Origin        object
# Harvest.Year            float64
# Expiration               object
# Variety                  object
# Color                    object
# Processing.Method        object
# Aroma                   float64
# Flavor                  float64
# Aftertaste              float64
# Acidity                 float64
# Body                    float64
# Balance                 float64
# Uniformity              float64
# Clean.Cup               float64
# Sweetness               float64
# Moisture                float64
# Quakers                   int64
# Category.One.Defects      int64
# Category.Two.Defects      int64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# REC_ID                    0
# Species                   0
# Continent.of.Origin       1
# Country.of.Origin         1
# Harvest.Year             60
# Expiration                0
# Variety                 226
# Color                   270
# Processing.Method       170
# Aroma                     0
# Flavor                    0
# Aftertaste                0
# Acidity                   0
# Body                      0
# Balance                   0
# Uniformity                0
# Clean.Cup                 0
# Sweetness                 0
# Moisture                  0
# Quakers                   0
# Category.One.Defects      0
# Category.Two.Defects      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# REC_ID                  0
# Species                 0
# Continent.of.Origin     0
# Country.of.Origin       0
# Harvest.Year            0
# Expiration              0
# Variety                 0
# Color                   0
# Processing.Method       0
# Aroma                   0
# Flavor                  0
# Aftertaste              0
# Acidity                 0
# Body                    0
# Balance                 0
# Uniformity              0
# Clean.Cup               0
# Sweetness               0
# Moisture                0
# Quakers                 0
# Category.One.Defects    0
# Category.Two.Defects    0
# dtype: int64

# %%
df.shape
# Out:
# (946, 22)

# %%
df.dtypes
# Out:
# REC_ID                    int64
# Species                  object
# Continent.of.Origin      object
# Country.of.Origin        object
# Harvest.Year            float64
# Expiration               object
# Variety                  object
# Color                    object
# Processing.Method        object
# Aroma                   float64
# Flavor                  float64
# Aftertaste              float64
# Acidity                 float64
# Body                    float64
# Balance                 float64
# Uniformity              float64
# Clean.Cup               float64
# Sweetness               float64
# Moisture                float64
# Quakers                   int64
# Category.One.Defects      int64
# Category.Two.Defects      int64
# dtype: object

# %% [raw]
# handelingdatatypes

# %%
df['Harvest.Year'] = df['Harvest.Year'].astype(int)

# %%
df['Harvest.Year']
# Out:
# 1       2014
# 4       2014
# 6       2012
# 9       2014
# 18      2015
#         ...
# 1308    2016
# 1309    2012
# 1319    2015
# 1322    2015
# 1333    2012
# Name: Harvest.Year, Length: 946, dtype: int32

# %%
df['Expiration'] = pd.to_datetime(df['Expiration'], format='%m/%d/%y')
df['Expiration'] = df['Expiration'].dt.year

# %%
df['Expiration']
# Out:
# 1       2016
# 4       2016
# 6       2013
# 9       2016
# 18      2017
#         ...
# 1308    2018
# 1309    2013
# 1319    2017
# 1322    2017
# 1333    2013
# Name: Expiration, Length: 946, dtype: int32

# %%
for col in df.columns:
    print(col)
    print(df[col].unique())
# Out:
# REC_ID
# [   1    4    6    9   18   21   22   25   27   29   32   33   35   40
#    43   44   45   47   48   49   52   53   54   55   57   58   62   66
#    67   68   69   71   73   75   76   77   78   79   80   84   85   86
#    88   91   92   96   97   98   99  101  102  107  108  109  110  112
#   113  115  116  120  121  122  125  126  128  129  130  132  133  135
#   136  137  138  139  141  145  146  147  148  149  152  153  154  155
#   156  157  158  159  160  161  162  163  164  165  166  168  171  172
#   173  174  175  176  179  181  182  184  185  186  191  192  193  194
#   195  196  197  198  199  200  201  202  203  204  205  206  207  208
#   209  210  211  212  213  214  215  216  217  219  220  221  222  224
#   225  226  227  228  229  230  231  232  233  234  236  237  238  241
#   242  243  244  245  246  248  249  250  251  252  253  254  255  256
#   258  259  260  261  262  268  269  270  271  273  274  276  277  279
#   280  282  283  284  285  287  288  289  291  296  297  298  300  301
#   302  303  304  305  306  307  308  310  314  315  316  317  318  319
#   323  324  325  326  327  328  329  330  331  332  333  335  336  337
#   338  339  340  342  343  344  346  347  349  350  351  353  354  355
#   356  357  358  361  362  364  365  366  367  368  369  370  371  372
#   375  376  377  378  380  381  383  384  385  386  387  388  389  390
#   391  397  398  399  400  401  402  403  404  405  406  408  409  410
#   411  413  416  417  419  420  422  423  424  425  426  427  428  429
#   430  431  432  433  434  435  436  440  441  442  445  446  447  448
#   449  450  451  452  454  456  458  459  460  461  462  463  464  467
#   468  469  471  472  473  474  478  479  480  481  482  483  484  485
#   486  488  491  496  497  498  499  500  502  503  504  505  506  507
#   508  509  510  511  512  513  514  515  516  517  518  519  520  522
#   523  524  525  533  534  535  536  537  538  539  540  541  542  543
#   544  545  546  547  549  550  551  552  553  555  556  559  560  561
#   562  563  564  565  566  569  570  571  572  573  574  575  579  580
#   581  582  583  584  585  587  588  589  590  591  592  593  594  595
#   596  597  598  599  602  603  604  605  607  608  609  610  613  615
#   616  617  618  619  620  621  622  624  625  633  634  638  640  642
#   643  646  648  649  650  651  653  654  655  656  659  660  661  662
#   663  664  665  667  669  670  671  672  674  675  676  677  678  679
#   680  682  683  684  685  686  688  689  691  692  693  694  695  696
#   697  698  700  702  703  705  706  708  709  710  711  712  713  714
#   715  716  717  719  720  721  722  723  724  726  728  729  730  731
#   732  733  736  737  738  739  740  741  742  743  744  746  747  748
#   749  750  751  752  753  754  756  757  759  760  761  763  764  765
#   766  767  769  770  771  774  775  778  779  780  781  782  783  785
#   786  787  788  789  790  791  792  794  795  796  797  798  799  800
#   801  803  804  805  806  807  808  809  810  811  812  813  815  816
#   817  818  819  820  821  825  826  829  830  831  833  834  835  836
#   837  838  839  840  841  842  843  844  846  847  848  849  850  851
#   852  853  854  855  859  860  861  864  865  866  868  870  871  872
#   873  877  878  879  880  881  882  883  885  886  887  888  889  890
#   891  892  893  894  895  896  897  898  899  900  902  903  904  910
#   911  912  914  915  916  917  918  919  920  921  922  923  924  925
#   926  927  928  929  930  931  934  935  936  937  938  939  940  941
#   942  944  947  951  953  954  955  956  957  958  959  962  963  964
#   965  966  967  968  969  970  972  973  974  975  976  978  979  980
#   981  982  983  984  987  990  991  992  994  995  996  997  999 1000
#  1001 1002 1003 1004 1005 1006 1007 1008 1009 1011 1012 1013 1014 1015
#  1016 1018 1019 1020 1021 1023 1024 1026 1027 1028 1030 1031 1032 1033
#  1034 1035 1038 1039 1040 1041 1042 1043 1044 1045 1046 1047 1048 1049
#  1050 1051 1052 1053 1054 1056 1057 1058 1062 1063 1064 1065 1068 1069
#  1070 1072 1073 1074 1076 1077 1080 1081 1082 1083 1084 1085 1087 1088
#  1089 1090 1091 1092 1094 1095 1096 1097 1098 1099 1100 1101 1102 1103
#  1107 1108 1109 1110 1111 1112 1114 1115 1117 1118 1119 1121 1122 1123
#  1124 1125 1127 1128 1131 1132 1133 1135 1136 1137 1140 1141 1142 1143
#  1144 1146 1149 1150 1151 1152 1154 1155 1157 1158 1160 1161 1166 1169
#  1171 1172 1173 1174 1175 1176 1178 1180 1181 1182 1183 1184 1185 1186
#  1187 1190 1192 1193 1195 1196 1198 1199 1202 1203 1204 1206 1208 1209
#  1212 1216 1217 1218 1221 1223 1224 1226 1227 1228 1229 1230 1231 1232
#  1234 1235 1236 1237 1238 1239 1240 1241 1243 1244 1245 1248 1249 1251
#  1252 1253 1254 1258 1259 1263 1264 1266 1270 1271 1274 1276 1277 1279
#  1280 1282 1285 1286 1287 1288 1290 1293 1296 1298 1299 1300 1301 1303
#  1304 1305 1307 1308 1309 1319 1322 1333]
# Species
# ['Arabica' 'Robusta']
# Continent.of.Origin
# ['Africa' 'South America' 'Asia' 'North America']
# Country.of.Origin
# ['Ethiopia' 'Peru' 'China' 'Costa Rica' 'Mexico' 'Brazil' 'Uganda'
#  'Taiwan' 'Kenya' 'Thailand' 'Colombia' 'Guatemala' 'Panama' 'El Salvador'
#  'Indonesia' 'United States' 'Tanzania' 'Honduras' 'Nicaragua' 'Haiti'
#  'Vietnam' 'Philippines' 'Rwanda' 'Malawi' 'Laos' 'Myanmar' 'India']
# Harvest.Year
# [2014 2012 2015 2011 2013 2016 2017 2018]
# Expiration
# [2016 2013 2017 2015 2012 2014 2018 2019]
# Variety
# ['Other' 'Catimor' 'Caturra' 'Bourbon' 'SL14' 'Sumatra' 'SL34' 'SL28'
#  'Gesha' 'Catuai' 'Pacamara' 'Sumatra Lintong' 'Hawaiian Kona' 'Typica'
#  'Mundo Novo' 'Java' 'Peaberry' 'Pacas' 'Mandheling' 'Yellow Bourbon'
#  'Ruiru 11' 'Ethiopian Heirlooms' 'Moka Peaberry' 'Arusha' 'Sulawesi'
#  'Blue Mountain']
# Color
# ['Green' 'Bluish-Green' 'Blue-Green']
# Processing.Method
# ['Washed / Wet' 'Natural / Dry' 'Pulped natural / honey'
#  'Semi-washed / Semi-pulped' 'Other']
# Aroma
# [8.75 8.25 8.42 8.08 8.17 8.5  8.   7.83 8.33 7.75 7.92 7.58 7.67 7.42
#  7.33 7.5  7.81 7.25 7.17 7.08 5.08 6.92 7.   6.83 6.5  6.33 6.67 6.75]
# Flavor
# [8.67 8.5  8.58 8.25 8.17 8.   7.83 8.33 8.08 7.92 7.75 7.58 7.67 7.5
#  7.88 7.42 7.33 7.25 7.   7.08 7.17 6.92 6.83 6.5  6.75 6.08 6.17 6.58
#  6.33 6.67]
# Aftertaste
# [8.5  8.25 8.33 8.08 8.   8.17 7.83 7.75 7.92 7.67 7.58 7.5  7.42 7.33
#  7.56 7.25 7.17 7.08 6.83 6.92 7.   6.75 6.33 6.58 6.67 6.5  6.17 6.42]
# Acidity
# [8.58 8.5  8.17 8.   8.25 7.75 8.08 8.33 7.92 7.67 7.83 7.58 7.17 7.42
#  7.5  7.25 8.42 7.33 7.08 7.   6.92 5.25 6.83 6.75 6.67 6.5  6.25]
# Body
# [8.42 8.25 7.67 7.92 8.   7.83 7.58 7.75 8.08 7.5  7.63 7.42 7.33 8.17
#  7.25 7.17 7.   7.08 6.75 6.83 6.92 6.67 6.33 6.5  6.42]
# Balance
# [8.42 8.33 8.25 8.   8.17 7.92 7.83 8.08 7.75 8.58 8.5  7.67 7.58 7.5
#  7.33 7.42 7.17 7.25 6.83 7.08 7.   6.92 6.58 6.75 6.67 6.5  6.17 6.08]
# Uniformity
# [10.    9.33  8.67  6.67  8.    7.33  6.  ]
# Clean.Cup
# [10.    8.67  9.33  6.67  8.    5.33  7.33  6.    2.67  1.33]
# Sweetness
# [10.    9.33  6.67  8.67  8.    6.    1.33  7.92  7.75  7.58]
# Moisture
# [0.12 0.11 0.1  0.13 0.   0.08 0.09 0.06 0.14 0.07 0.17]
# Quakers
# [ 0  1  3  4 11  2  7  5  6  8]
# Category.One.Defects
# [ 0  1  2  6  4  3 10  5 31 11  7 23 15  8]
# Category.Two.Defects
# [ 1  2  0  4  9  3  7  5  6  8 29 10 40 26 32 13 11 21 14 12 20 16 15 23
#  17 22 30 19 34 45 38 47 31 28 24]

# %% [raw]
# drdroping the redc_id column as it does not provide any meaning ful info for analysis.

# %%
df = df.drop('REC_ID', axis=1)

# %%
df.columns
# Out:
# Index(['Species', 'Continent.of.Origin', 'Country.of.Origin', 'Harvest.Year',
#        'Expiration', 'Variety', 'Color', 'Processing.Method', 'Aroma',
#        'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity',
#        'Clean.Cup', 'Sweetness', 'Moisture', 'Quakers', 'Category.One.Defects',
#        'Category.Two.Defects'],
#       dtype='object')

# %% [raw]
# creating new feature from 'Category.One.Defects',
#        'Category.Two.Defects'

# %%
df['Defective'] = df['Category.One.Defects'] + df['Category.Two.Defects']
df['Defective'] = df['Defective'].astype(int)
df['Defective']
# Out:
# 1       1
# 4       2
# 6       0
# 9       4
# 18      0
#        ..
# 1308    6
# 1309    4
# 1319    0
# 1322    0
# 1333    0
# Name: Defective, Length: 946, dtype: int32

# %%
df['Color'] = df['Color'].replace(['Bluish-Green', 'Blue-Green'], 'Bluish-green')
df.Color.unique()
# Out:
# array(['Green', 'Bluish-green'], dtype=object)

# %%
import category_encoders as ce
encoder = ce.OrdinalEncoder(mapping=[{'col': 'Species', 'mapping': {'Arabica': 1, 'Robusta': 2}}, 
                                    {'col': 'Color', 'mapping': {'Green': 1, 'Bluish-green':2}},
                                     {'col': 'Processing.Method', 'mapping': {'Washed / Wet': 1, 'Natural / Dry': 2, 'Pulped natural / honey': 3, 'Semi-washed / Semi-pulped': 4, 'Other': 5}},
                                     {'col': 'Continent.of.Origin', 'mapping': {'Africa': 1, 'South America': 2, 'Asia': 3, 'North America': 4}},
                                     {'col': 'Country.of.Origin', 'mapping': {'Ethiopia': 1, 'Peru': 2, 'China': 3, 'Costa Rica': 4, 'Mexico': 5, 'Brazil': 6, 'Uganda': 7, 'Taiwan': 8, 'Kenya': 9, 'Thailand': 10, 'Colombia': 11, 'Guatemala': 12, 'Panama': 13, 'El Salvador': 14, 'Indonesia': 15, 'United States': 16, 'Tanzania': 17, 'Honduras': 18, 'Nicaragua': 19, 'Haiti': 20, 'Vietnam': 21, 'Philippines': 22, 'Rwanda': 23, 'Malawi': 24, 'Laos': 25, 'Myanmar': 26, 'India': 27}
}
                                    ])
encoder.fit(df)
df = encoder.transform(df)
df.Species
# Out:
# 1       1
# 4       1
# 6       1
# 9       1
# 18      1
#        ..
# 1308    1
# 1309    1
# 1319    2
# 1322    2
# 1333    2
# Name: Species, Length: 946, dtype: int32

# %%
features = ['Species','Continent.of.Origin','Harvest.Year', 'Aroma', 'Flavor', 'Acidity', 'Uniformity','Processing.Method', 'Country.of.Origin','Moisture', 'Balance', 'Uniformity','Clean.Cup']
y = df['Defective']
x = df[features]
for i in range(20):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

    rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, oob_score=True, random_state=42)
    rf.fit(x,y)
    val_score = rf.score(X_test, y_test)
    print(f"Validation R^2 for noisy model is: {val_score}")
    print(rf.oob_score_)
# Out:
# Validation R^2 for noisy model is: 0.8901169591174319
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.882893358768432
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.918666536482746
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8958521902458202
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8970211760670189
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8634666845672038
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8668929592861665
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.9088600580524775
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8848506635786655
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.889429901003251
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.878109386235002
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8634405029380913
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8902373235771849
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.905133010359113
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.9012322749374139
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.9130235819853915
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8491119554000319
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.833901609889608
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8206306796675737
# 0.10466609136736171
# Validation R^2 for noisy model is: 0.8696019389941696
# 0.10466609136736171

# %% [raw]
# CLASSIFICATION

# %%
X = df[['Color' , 'Country.of.Origin', 'Continent.of.Origin', 'Harvest.Year']]
Y = df[['Species']]

for i in range(20):
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
    clf = DecisionTreeClassifier(random_state=42)

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)


    # Evaluate model performance
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy:", accuracy)

    # Print classification report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Print confusion matrix
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       189
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
# Confusion Matrix:
# [[189   0]
#  [  0   1]]

# %%
print(clf.predict([[1, 6,2, 2011 ]]))
# Out:
# [1]
# C:\Users\rande\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
